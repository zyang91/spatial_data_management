# %%
import ee
import geemap
import geopandas as gpd
geemap.ee_initialize()

# %%
data ='https://github.com/gee-community/geemap/blob/master/examples/data/us_cities.csv'
geemap.csv_to_df(data)

# %%
geemap.csv_to_geojson(data, 'cities.geojson', latitude='latitude', longitude='longitude')

# %%
geemap.csv_to_shp(data, 'cities.shp', latitude='latitude', longitude='longitude')
geemap.csv_to_gdf(data, latitude='latitude', longitude='longitude')
geemap.csv_to_vector(data, 'cities.gpkg', latitude='latitude', longitude='longitude')

# %%
gdf= geemap.csv_to_gdf(data, latitude='latitude', longitude='longitude')
gdf

# %%
regions= 'https://github.com/gee-community/geemap/blob/master/examples/data/us_regions.geojson'

# %%
m= geemap.Map(center=[40,-100], zoom=4)
m.add_geojson(regions, layer_name='US Regions')
m.add_points_from_xy(
    data,
    x='longitude',
    y='latitude',
    layer_name='US Cities',
    color_column= 'region',
    icon_names= ['gear', 'cloud', 'home', 'star'],
    spin= True,
    add_legend= True,
    
)
m

# %%
Map= geemap.Map(center=[40,-100], zoom=4)
Map.add_circle_markers_from_xy(
    data,
    x='longitude',
    y='latitude',
    radius=4,
    color='red',
    fill_color='red',
    fill_opacity=1,
)
Map

# %% [markdown]
# ## Vector data to Earth Engine

# %%
geojson= 'https://github.com/gee-community/geemap/blob/master/examples/data/us_cities.geojson'
Map= geemap.Map(center=[40,-100], zoom=4)
fc= geemap.geojson_to_ee(geojson)
Map.addLayer(fc, {}, 'US Cities')
Map

# %% [markdown]
# ## join attribute table

# %%
Map= geemap.Map()
countires= ee.FeatureCollection(geemap.examples.get_ee_path('countries'))
Map.addLayer(countires, {}, 'Countries')
Map

# %%
geemap.ee_to_df(countires)

# %%
data= 'https://github.com/gee-community/geemap/blob/master/examples/data/country_centroids.csv'
df= geemap.csv_to_df(data)
df

# %%
fc= geemap.ee_join_table(countires, data, src_key='ISO_A2', dst_key='country')
geemap.ee_to_df(fc)

# %% [markdown]
# ### Open Street Map

# %%
gdf= geemap.osm_to_gdf('Binghamton, New York')
gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-75.95013 42.11084, -75.94896 42.100...   42.131497   42.071984
#
#    bbox_east  bbox_west  place_id  osm_type  osm_id        lat        lon  \
# 0 -75.856933 -75.950133   9519552  relation  174933  42.098698 -75.912519
#
#       class            type  place_rank  importance addresstype  \
# 0  boundary  administrative          14    0.520977        city
#
#                  name                                       display_name
# 0  City of Binghamton  City of Binghamton, Broome County, New York, 1...

# %%
gdf.explore()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c8579a63022b81f1cd9e334411d65e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c8579a63022b81f1cd9e334411d65e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c8579a63022b81f1cd9e334411d65e8 = L.map(
#                 &quot;map_7c8579a63022b81f1cd9e334411d65e8&quot;,
#                 {
#                     center: [42.101740500000005, -75.903533],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7c8579a63022b81f1cd9e334411d65e8);
#
#
#
#
#
#             var tile_layer_65399f58f277a5dad43152591183265c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_65399f58f277a5dad43152591183265c.addTo(map_7c8579a63022b81f1cd9e334411d65e8);
#
#
#             map_7c8579a63022b81f1cd9e334411d65e8.fitBounds(
#                 [[42.071984, -75.950133], [42.131497, -75.856933]],
#                 {}
#             );
#
#
#         function geo_json_ee73c8d9a5dd0568126213a0a17e34cd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ee73c8d9a5dd0568126213a0a17e34cd_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ee73c8d9a5dd0568126213a0a17e34cd_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ee73c8d9a5dd0568126213a0a17e34cd_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ee73c8d9a5dd0568126213a0a17e34cd_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ee73c8d9a5dd0568126213a0a17e34cd.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ee73c8d9a5dd0568126213a0a17e34cd_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ee73c8d9a5dd0568126213a0a17e34cd = L.geoJson(null, {
#                 onEachFeature: geo_json_ee73c8d9a5dd0568126213a0a17e34cd_onEachFeature,
#
#                 style: geo_json_ee73c8d9a5dd0568126213a0a17e34cd_styler,
#                 pointToLayer: geo_json_ee73c8d9a5dd0568126213a0a17e34cd_pointToLayer,
#         });
#
#         function geo_json_ee73c8d9a5dd0568126213a0a17e34cd_add (data) {
#             geo_json_ee73c8d9a5dd0568126213a0a17e34cd
#                 .addData(data);
#         }
#             geo_json_ee73c8d9a5dd0568126213a0a17e34cd_add({&quot;bbox&quot;: [-75.950133, 42.071984, -75.856933, 42.131497], &quot;features&quot;: [{&quot;bbox&quot;: [-75.950133, 42.071984, -75.856933, 42.131497], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-75.950133, 42.110842], [-75.948963, 42.100249], [-75.949073, 42.099374], [-75.9488645, 42.0978929], [-75.948849, 42.097783], [-75.948391, 42.093811], [-75.948322, 42.093378], [-75.948286, 42.092865], [-75.94724, 42.083735], [-75.933414, 42.084595], [-75.931552, 42.084721], [-75.92971, 42.084811], [-75.928363, 42.071984], [-75.922231, 42.072355], [-75.920514, 42.072475], [-75.910638, 42.073094], [-75.901021, 42.073794], [-75.90123, 42.075702], [-75.901761, 42.080018], [-75.89724, 42.080365], [-75.896892, 42.077411], [-75.896753, 42.07742], [-75.896657, 42.077522], [-75.89645, 42.077698],

# %%
Map= geemap.Map()
binghamton= geemap.osm_to_ee('Binghamton, New York')
Map.addLayer(binghamton, {}, 'Binghamton')
Map.centerObject(binghamton, 10)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[42.101371603869325, -75.9092528776403], controls=(WidgetControl(options=['position', 'transparent_…

# %%
import geemap.osm as osm
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map= geemap.Map(add_google_map= False)
gdf= osm.osm_gdf_from_geocode('Seattle, Washington')
Map.add_gdf(gdf, layer_name='Seattle')
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
place = 'University of Pennsylvania, Philadelphia, PA'
tags= {'building': True}
gdf= osm.osm_gdf_from_place(place, tags)
gdf= gdf[gdf.geometry.type == 'Polygon']
gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                       wheelchair  \
# element_type osmid
# way          32119117        NaN
#              32119145        NaN
#              32119148        NaN
#              32119156        NaN
#              32119197        NaN
# ...                          ...
# relation     5231600         NaN
#              5231601         NaN
#              5235124         NaN
#              10335155        NaN
#              11041533        NaN
#
#                                                                 geometry  \
# element_type osmid
# way          32119117  POLYGON ((-75.19768 39.95263, -75.19734 39.952...
#              32119145  POLYGON ((-75.19782 39.95311, -75.19779 39.953...
#              32119148  POLYGON ((-75.19755 39.95337, -75.19692 39.953...
#              32119156  POLYGON ((-75.19717 39.95305, -75.19692 39.953...
#              32119197  POLYGON ((-75.19760 39.95187, -75.19763 39.951...
# ...                                                                  ...
# relation     5231600   POLYGON ((-75.19837 39.95231, -75.19829 39.952...
#              5231601   POLYGON ((-75.19161 39.94998, -75.19165 39.949...
#              5235124   POLYGON ((-75.19104 39.95325, -75.19013 39.953...
#              10335155  POLYGON ((-75.19476 39.94886, -75.19448 39.949...
#              11041533  POLYGON ((-75.20178 39.95387, -75.20181 39.953...
#
#                       addr:state    building  ele gnis:feature_id  \
# element_type osmid
# way          32119117        NaN  university  NaN             NaN
#              32119145        NaN  university  NaN             NaN
#              32119148        NaN  university  NaN             NaN
#              32119156        NaN  university  NaN             NaN
#              32119197        NaN  university  NaN             NaN
# ...                          ...         ...  ...             ...
# relation     5231600         NaN  university  NaN             NaN
#              5231601         NaN         yes  NaN             NaN
#              5235124         NaN   dormitory  NaN             NaN
#              10335155        NaN    hospital  NaN             NaN
#              11041533         PA   dormitory  NaN             NaN
#
#                                                name  \
# element_type osmid
# way          32119117               Caster Building
#              32119145                   Solomon Lab
#              32119148  Graduate School of Education
#              32119156                 Stiteler Hall
#              32119197           Lauder Fischer Hall
# ...                                             ...
# relation     5231600    Steinberg Conference Center
#              5231601                    Penn Museum
#              5235124             Hill College House
#              10335155            CHOP Main Building
#              11041533         Gutmann College House
#
#                                                  source     addr:city  \
# element_type osmid
# way          32119117                               NaN  Philadelphia
#              32119145                               NaN  Philadelphia
#              32119148                               NaN  Philadelphia
#              32119156                               NaN  Philadelphia
#              32119197                               NaN  Philadelphia
# ...                                                 ...           ...
# relation     5231600                                NaN  Philadelphia
#              5231601                                NaN  Philadelphia
#              5235124                                NaN  Philadelphia
#              10335155                               NaN           NaN
#              11041533  EsriWorldImagery;local knowledge  Philadelphia
#
#                       addr:housename  ... bench  bin supervised note comment  \
# element_type osmid                    ...
# way          32119117            NaN  ...   NaN  NaN        NaN  NaN     NaN
#              32119145    Solomon Lab  ...   NaN  NaN        NaN  NaN     NaN
#              32119148            NaN  ...   NaN  NaN        NaN  NaN     NaN
#              32119156            NaN  ...   NaN  NaN        NaN  NaN     NaN
#              32119197            NaN  ...   NaN  NaN        NaN  NaN     NaN
# ...                              ...  ...   ...  ...        ...  ...     ...
# relation     5231600             NaN  ...   NaN  NaN        NaN  NaN     NaN
#              5231601             NaN  ...   NaN  NaN        NaN  NaN     NaN
#              5235124             NaN  ...   NaN  NaN        NaN  NaN     NaN
#              10335155            NaN  ...   NaN  NaN        NaN  NaN     NaN
#              11041533            NaN  ...   NaN  NaN        NaN  NaN     NaN
#
#                       house fixme min_height  \
# element_type osmid
# way          32119117   NaN   NaN        NaN
#              32119145   NaN   NaN        NaN
#              32119148   NaN   NaN        NaN
#              32119156   NaN   NaN        NaN
#              32119197   NaN   NaN        NaN
# ...                     ...   ...        ...
# relation     5231600    NaN   NaN        NaN
#              5231601    NaN   NaN        NaN
#              5235124    NaN   NaN        NaN
#              10335155   NaN   NaN        NaN
#              11041533   NaN   NaN        NaN
#
#                                                    ways          type
# element_type osmid
# way          32119117                               NaN           NaN
#              32119145                               NaN           NaN
#              32119148                               NaN           NaN
#              32119156                               NaN           NaN
#              32119197                               NaN           NaN
# ...                                                 ...           ...
# relation     5231600              [51469718, 350720978]  multipolygon
#              5231601              [50032991, 350720983]  multipolygon
#              5235124   [32108058, 351053392, 351053393]  multipolygon
#              10335155            [749536281, 749536275]  multipolygon
#              11041533            [797025837, 797025836]  multipolygon
#
# [292 rows x 75 columns]

# %%
m= geemap.Map(add_google_map= False)
m.add_gdf(gdf, layer_name='UPenn_buildings')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
gdf= osm.osm_gdf_from_address(address=place, tags={'amenity': 'bar'}, dist=1500)
gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                          amenity                         name  \
# element_type osmid
# node         655425272       bar                Drinkers West
#              1033935437      bar              Mix Bar & Grill
#              1700198702      bar                 Smokey Joe's
#              1980171513      bar                  SideCar Bar
#              2182345789      bar                  Flynn's Bar
#              2931994044      bar  Señor Baynard's Bar & Grill
#              6669293565      bar         Point Breeze Brewing
#              8410340130      bar                       Bar210
#              8410340131      bar              The Library Bar
#              10542176918     bar               Pace & Blossom
#              10682204580     bar       The Living Room Lounge
#              11018275014     bar                  Butcher Bar
#              11897497290     bar                  Human Robot
# way          350991334       bar           Bonner's Irish Pub
#
#                                                                    geometry  \
# element_type osmid
# node         655425272                           POINT (-75.20020 39.95521)
#              1033935437                          POINT (-75.17552 39.95242)
#              1700198702                          POINT (-75.20283 39.95374)
#              1980171513                          POINT (-75.17945 39.94177)
#              2182345789                          POINT (-75.20250 39.95707)
#              2931994044                          POINT (-75.17221 39.93599)
#              6669293565                          POINT (-75.19007 39.93834)
#              8410340130                          POINT (-75.17321 39.95003)
#              8410340131                          POINT (-75.17305 39.95000)
#              10542176918                         POINT (-75.19442 39.95630)
#              10682204580                         POINT (-75.19579 39.95375)
#              11018275014                         POINT (-75.17489 39.95212)
#              11897497290                         POINT (-75.18008 39.95155)
# way          350991334    POLYGON ((-75.17859 39.95202, -75.17860 39.951...
#
#                          addr:housenumber              addr:street  \
# element_type osmid
# node         655425272                NaN                      NaN
#              1033935437              2101          Chestnut Street
#              1700198702               NaN                      NaN
#              1980171513               NaN                      NaN
#              2182345789               NaN                      NaN
#              2931994044              1216        South 17th Street
#              6669293565               NaN                      NaN
#              8410340130               210  West Rittenhouse Square
#              8410340131               210  West Rittenhouse Square
#              10542176918             3601            Market Street
#              10682204580             3600            Sansom Street
#              11018275014             2034          Chestnut Street
#              11897497290              NaN                      NaN
# way          350991334                120        South 23rd Street
#
#                             contact:phone  \
# element_type osmid
# node         655425272                NaN
#              1033935437   +1 215-568-3355
#              1700198702               NaN
#              1980171513               NaN
#              2182345789               NaN
#              2931994044               NaN
#              6669293565               NaN
#              8410340130               NaN
#              8410340131               NaN
#              10542176918              NaN
#              10682204580              NaN
#              11018275014              NaN
#              11897497290              NaN
# way          350991334                NaN
#
#                                                             contact:website  \
# element_type osmid
# node         655425272                                                  NaN
#              1033935437   https://mixbarandgrillphilly.com/location/mix-...
#              1700198702                                                 NaN
#              1980171513                                                 NaN
#              2182345789                                                 NaN
#              2931994044                                                 NaN
#              6669293565                                                 NaN
#              8410340130                                                 NaN
#              8410340131   https://www.rittenhousehotel.com/dining/librar...
#              10542176918                                                NaN
#              10682204580                                                NaN
#              11018275014                                                NaN
#              11897497290                                                NaN
# way          350991334                                                  NaN
#
#                                                             description  \
# element_type osmid
# node         655425272                                              NaN
#              1033935437   The bar is open until whenever the rush ends.
#              1700198702                                             NaN
#              1980171513                                             NaN
#              2182345789                                             NaN
#              2931994044                                             NaN
#              6669293565                                             NaN
#              8410340130                                  inside Lacroix
#              8410340131                                             NaN
#              10542176918                                            NaN
#              10682204580                                            NaN
#              11018275014                                            NaN
#              11897497290                                            NaN
# way          350991334                                              NaN
#
#                                                               opening_hours  \
# element_type osmid
# node         655425272                                                  NaN
#              1033935437             Mo-We,Su 11:00-22:00; Th-Sa 11:00-23:00
#              1700198702                                                 NaN
#              1980171513                                   Th-Tu 16:00-23:00
#              2182345789                                                 NaN
#              2931994044                                                 NaN
#              6669293565                                                 NaN
#              8410340130   Mo-Tu off; We-Th 17:00-21:00; Fr-Sa 14:00-21:3...
#              8410340131             Mo-Th,Su 17:00-23:00; Fr-Sa 17:00-24:30
#              10542176918                                                NaN
#              10682204580                                                NaN
#              11018275014  Mo 11:30-22:00, Tu,Fr-Sa 11:30-26:00, We-Th 11...
#              11897497290                                                NaN
# way          350991334                                                  NaN
#
#                          outdoor_seating  ...            phone smoking  \
# element_type osmid                        ...
# node         655425272               NaN  ...              NaN     NaN
#              1033935437              yes  ...              NaN     NaN
#              1700198702              NaN  ...              NaN     NaN
#              1980171513              yes  ...              NaN     NaN
#              2182345789              NaN  ...              NaN     NaN
#              2931994044              NaN  ...  +1 215 462 1888     yes
#              6669293565              NaN  ...              NaN     NaN
#              8410340130              NaN  ...  +1 215-546-9000     NaN
#              8410340131              NaN  ...  +1 215-546-9000     NaN
#              10542176918             NaN  ...              NaN     NaN
#              10682204580             NaN  ...              NaN     NaN
#              11018275014             NaN  ...  +1 215-563-6328     NaN
#              11897497290             yes  ...              NaN     NaN
# way          350991334               NaN  ...  +1 215-567-5748     NaN
#
#                             craft  check_date addr:state  \
# element_type osmid
# node         655425272        NaN         NaN        NaN
#              1033935437       NaN         NaN        NaN
#              1700198702       NaN         NaN        NaN
#              1980171513       NaN         NaN        NaN
#              2182345789       NaN         NaN        NaN
#              2931994044       NaN         NaN        NaN
#              6669293565   brewery         NaN        NaN
#              8410340130       NaN  2023-10-14        NaN
#              8410340131       NaN  2023-10-15        NaN
#              10542176918      NaN         NaN         PA
#              10682204580      NaN         NaN         PA
#              11018275014      NaN  2023-10-10         PA
#              11897497290      NaN         NaN        NaN
# way          350991334        NaN  2023-10-10         PA
#
#                                                 contact:facebook      brewery  \
# element_type osmid
# node         655425272                                       NaN          NaN
#              1033935437                                      NaN          NaN
#              1700198702                                      NaN          NaN
#              1980171513                                      NaN          NaN
#              2182345789                                      NaN          NaN
#              2931994044                                      NaN          NaN
#              6669293565                                      NaN          NaN
#              8410340130                                      NaN          NaN
#              8410340131                                      NaN          NaN
#              10542176918                                     NaN          NaN
#              10682204580                                     NaN          NaN
#              11018275014  https://www.facebook.com/ButcherBarPHL          NaN
#              11897497290                                     NaN  Human Robot
# way          350991334                                       NaN          NaN
#
#                                                                       nodes  \
# element_type osmid
# node         655425272                                                  NaN
#              1033935437                                                 NaN
#              1700198702                                                 NaN
#              1980171513                                                 NaN
#              2182345789                                                 NaN
#              2931994044                                                 NaN
#              6669293565                                                 NaN
#              8410340130                                                 NaN
#              8410340131                                                 NaN
#              10542176918                                                NaN
#              10682204580                                                NaN
#              11018275014                                                NaN
#              11897497290                                                NaN
# way          350991334    [3567104221, 3567104222, 3567104223, 356710422...
#
#                          building                          contact:instagram
# element_type osmid
# node         655425272        NaN                                        NaN
#              1033935437       NaN                                        NaN
#              1700198702       NaN                                        NaN
#              1980171513       NaN                                        NaN
#              2182345789       NaN                                        NaN
#              2931994044       NaN                                        NaN
#              6669293565       NaN                                        NaN
#              8410340130       NaN                                        NaN
#              8410340131       NaN                                        NaN
#              10542176918      NaN                                        NaN
#              10682204580      NaN                                        NaN
#              11018275014      NaN                                        NaN
#              11897497290      NaN                                        NaN
# way          350991334        yes  https://www.instagram.com/bonnersirishpub
#
# [14 rows x 24 columns]

# %%
Map= geemap.Map(add_google_map= False)
Map.add_gdf(gdf, layer_name='Bars')
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
gdf= osm.osm_gdf_from_point((39.9526, -75.1652), tags={'natural': 'water'}, dist=10000)
gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                                                 geometry  ele  \
# element_type osmid
# way          29705600  POLYGON ((-75.07950 39.90854, -75.08023 39.908...  NaN
#              30105019  POLYGON ((-75.07296 39.91121, -75.07313 39.911...  NaN
#              32110446  POLYGON ((-75.19805 39.94918, -75.19810 39.949...  NaN
#              49887287  POLYGON ((-75.19292 39.98285, -75.19238 39.982...  NaN
#              49916251  POLYGON ((-75.21684 39.98038, -75.21693 39.980...  NaN
# ...                                                                  ...  ...
# relation     16314856  POLYGON ((-75.21261 39.98138, -75.21261 39.981...  NaN
#              16786124  POLYGON ((-75.26974 40.05897, -75.26886 40.059...  NaN
#              16786126  POLYGON ((-75.24615 40.03987, -75.24605 40.039...  NaN
#              17217251  POLYGON ((-75.08567 39.92775, -75.08567 39.927...  NaN
#              17558030  POLYGON ((-75.19544 39.97223, -75.19542 39.972...  NaN
#
#                                       name      water waterway leisure canoe  \
# element_type osmid
# way          29705600          Newton Lake     stream      NaN     NaN   NaN
#              30105019                  NaN       pond      NaN     NaN   NaN
#              32110446         Biology Pond       pond      NaN     NaN   NaN
#              49887287  East Park Reservoir  reservoir      NaN     NaN   NaN
#              49916251       Concourse Lake        NaN      NaN     NaN   NaN
# ...                                    ...        ...      ...     ...   ...
# relation     16314856                  NaN       pond      NaN     NaN   NaN
#              16786124                  NaN  reservoir      NaN     NaN   NaN
#              16786126                  NaN      canal      NaN     NaN   NaN
#              17217251                  NaN        NaN      NaN     NaN   NaN
#              17558030                  NaN       pond      NaN     NaN   NaN
#
#                       description sport source  ... start_date waterway:name  \
# element_type osmid                              ...
# way          29705600         NaN   NaN    NaN  ...        NaN           NaN
#              30105019         NaN   NaN    NaN  ...        NaN           NaN
#              32110446         NaN   NaN    NaN  ...        NaN           NaN
#              49887287         NaN   NaN    NaN  ...        NaN           NaN
#              49916251         NaN   NaN    NaN  ...        NaN           NaN
# ...                           ...   ...    ...  ...        ...           ...
# relation     16314856         NaN   NaN    NaN  ...        NaN           NaN
#              16786124         NaN   NaN    NaN  ...        NaN           NaN
#              16786126         NaN   NaN    NaN  ...        NaN           NaN
#              17217251         NaN   NaN    NHD  ...        NaN           NaN
#              17558030         NaN   NaN    NaN  ...        NaN           NaN
#
#                       athletics golf  \
# element_type osmid
# way          29705600       NaN  NaN
#              30105019       NaN  NaN
#              32110446       NaN  NaN
#              49887287       NaN  NaN
#              49916251       NaN  NaN
# ...                         ...  ...
# relation     16314856       NaN  NaN
#              16786124       NaN  NaN
#              16786126       NaN  NaN
#              17217251       NaN  NaN
#              17558030       NaN  NaN
#
#                                                                     ways  \
# element_type osmid
# way          29705600                                                NaN
#              30105019                                                NaN
#              32110446                                                NaN
#              49887287                                                NaN
#              49916251                                                NaN
# ...                                                                  ...
# relation     16314856                             [688957323, 111481577]
#              16786124  [1228754522, 48001955, 1228754518, 658956335, ...
#              16786126  [1228754528, 1228754527, 658953601, 658953603,...
#              17217251                 [118838667, 1250744431, 603068773]
#              17558030                           [1279719822, 1279719823]
#
#                                type fishing waterway:wikidata  \
# element_type osmid
# way          29705600           NaN     NaN               NaN
#              30105019           NaN     NaN               NaN
#              32110446           NaN     NaN               NaN
#              49887287           NaN     NaN               NaN
#              49916251           NaN     NaN               NaN
# ...                             ...     ...               ...
# relation     16314856  multipolygon     NaN               NaN
#              16786124  multipolygon     NaN               NaN
#              16786126  multipolygon     NaN               NaN
#              17217251  multipolygon     NaN               NaN
#              17558030  multipolygon     NaN               NaN
#
#                       waterway:wikipedia nrhp:nhl
# element_type osmid
# way          29705600                NaN      NaN
#              30105019                NaN      NaN
#              32110446                NaN      NaN
#              49887287                NaN      NaN
#              49916251                NaN      NaN
# ...                                  ...      ...
# relation     16314856                NaN      NaN
#              16786124                NaN      NaN
#              16786126                NaN      NaN
#              17217251                NaN      NaN
#              17558030                NaN      NaN
#
# [301 rows x 63 columns]

# %%
m= geemap.Map(add_google_map= False)
m.add_gdf(gdf, layer_name='Rivers')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
Map=geemap.Map(center= [47.6004,-122.3228], zoom= 16, add_google_map= False)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[47.6004, -122.3228], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=Search…

# %%
Map.add_osm_from_view(tags={'amenity': 'bar', 'building': True})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
