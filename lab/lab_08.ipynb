# %% [markdown]
# # Lab 8
#
# **Submission requirements**
#
# 1. An HTML version of your notebook (VS Code > Notebook > Export > HTML). The HTML file must show the output of your code.
# 2. A link to your notebook on Colab.
#
# **Datasets**:
#
# The following datasets are used in this lab. You don't need to download them manually, they can be accessed directly from the notebook.
#
# - [nyc_subway_stations.tsv](https://open.gishub.org/data/duckdb/nyc_subway_stations.tsv)
# - [nyc_neighborhoods.tsv](https://open.gishub.org/data/duckdb/nyc_neighborhoods.tsv)

# %%
# %pip install duckdb duckdb-engine jupysql

# %%
import duckdb

# %load_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///:memory:

# %%
# %%sql
#
# INSTALL httpfs;
# LOAD httpfs;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Question 1: Creating Tables
#
# Create a database, then write a SQL query to create a table named `nyc_subway_stations` and load the data from the file `nyc_subway_stations.tsv` into it. Similarly, create a table named `nyc_neighborhoods` and load the data from the file `nyc_neighborhoods.tsv` into it.

# %%
# %%sql
# CREATE TABLE nyc_subway_stations AS SELECT * FROM read_csv_auto('https://open.gishub.org/data/duckdb/nyc_subway_stations.tsv', header= True);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# FROM nyc_subway_stations;
# Out:
#      OBJECTID     ID               NAME         ALT_NAME         CROSS_ST  \
# 0           1  376.0       Cortlandt St             None        Church St
# 1           2    2.0          Rector St             None             None
# 2           3    1.0        South Ferry             None             None
# 3           4  125.0           138th St  Grand Concourse  Grand Concourse
# 4           5  126.0           149th St  Grand Concourse  Grand Concourse
# ..        ...    ...                ...              ...              ...
# 486       487  909.0     JFK Terminal 8             None             None
# 487       488  903.0     Federal Circle       Rental Car             None
# 488       489  902.0  Long Term Parking             None             None
# 489       490  901.0       Howard Beach             None        159th Ave
# 490       491  900.0            Jamaica     Sutphin Blvd     Sutphin Blvd
#
#                                   LONG_NAME                             LABEL  \
# ...

# %%
# %%sql
# CREATE TABLE nyc_neighborhoods AS SELECT * FROM read_csv_auto('https://open.gishub.org/data/duckdb/nyc_neighborhoods.tsv', header= True);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# FROM nyc_neighborhoods;
# Out:
#           BORONAME                      NAME
# 0         Brooklyn               Bensonhurst
# 1        Manhattan              East Village
# 2        Manhattan              West Village
# 3        The Bronx              Throggs Neck
# 4        The Bronx  Wakefield-Williamsbridge
# ..             ...                       ...
# 124       Brooklyn                  Red Hook
# 125         Queens   Douglastown-Little Neck
# 126         Queens                Whitestone
# 127         Queens                  Steinway
# 128  Staten Island                  Rosebank
#
# [129 rows x 2 columns]

# %% [markdown]
# ## Question 2: Column Filtering
#
# Write a SQL query to display the `ID`, `NAME`, and `BOROUGH` of each subway station in the `nyc_subway_stations` dataset.

# %%
# %%sql
#
# SELECT ID, NAME, BOROUGH FROM nyc_subway_stations;
# Out:
#         ID               NAME    BOROUGH
# 0    376.0       Cortlandt St  Manhattan
# 1      2.0          Rector St  Manhattan
# 2      1.0        South Ferry  Manhattan
# 3    125.0           138th St      Bronx
# 4    126.0           149th St      Bronx
# ..     ...                ...        ...
# 486  909.0     JFK Terminal 8     Queens
# 487  903.0     Federal Circle     Queens
# 488  902.0  Long Term Parking     Queens
# 489  901.0       Howard Beach     Queens
# 490  900.0            Jamaica     Queens
#
# [491 rows x 3 columns]

# %% [markdown]
# ## Question 3: Row Filtering
#
# Write a SQL query to find all subway stations in the `nyc_subway_stations` dataset that are located in the borough of Manhattan.

# %%
# %%sql
# SELECT * FROM nyc_subway_stations WHERE BOROUGH = 'Manhattan';
# Out:
#      OBJECTID     ID                NAME     ALT_NAME          CROSS_ST  \
# 0           1  376.0        Cortlandt St         None         Church St
# 1           2    2.0           Rector St         None              None
# 2           3    1.0         South Ferry         None              None
# 3          25  296.0            W 4th St         None           6th Ave
# 4         242  121.0            103rd St         None     Lexington Ave
# ..        ...    ...                 ...          ...               ...
# 135       374   72.0             Wall St         None        William St
# 136       375  378.0        Whitehall St  South Ferry          Water St
# 137       383  491.0        Cortlandt St         None     West Broadway
# 138       480  492.0  World Trade Center  Chambers St         Church St
# 139       481   99.0            Times Sq      42nd St  7th Ave/Broadway
#
#                                           LONG_NAME  \
# ...

# %% [markdown]
# ## Question 4: Sorting Results
#
# Write a SQL query to list the subway stations in the `nyc_subway_stations` dataset in alphabetical order by their names.

# %%
# %%sql
# SELECT * FROM nyc_subway_stations ORDER BY NAME;
# Out:
#      OBJECTID     ID                NAME      ALT_NAME           CROSS_ST  \
# 0         244   22.0            103rd St          None           Broadway
# 1         243  192.0            103rd St          None  Central Park West
# 2         242  121.0            103rd St          None      Lexington Ave
# 3         376  174.0            103rd St  Corona Plaza      Roosevelt Ave
# 4         377  239.0            104th St          None        Liberty Ave
# ..        ...    ...                 ...           ...                ...
# 486        72  138.0            Woodlawn          None         Jerome Ave
# 487       480  492.0  World Trade Center   Chambers St          Church St
# 488       240  334.0         Wyckoff Ave    Myrtle Ave         Myrtle Ave
# 489       241  303.0             York St          None             Jay St
# 490        73  152.0          Zerega Ave          None    Westchester Ave
#
#                                           LONG_NAME  \
# ...

# %% [markdown]
# ## Question 5: Unique Values
#
# Write a SQL query to find the distinct boroughs represented in the `nyc_subway_stations` dataset.

# %%
# %%sql
# SELECT DISTINCT BOROUGH FROM nyc_subway_stations;
# Out:
#          BOROUGH
# 0      Manhattan
# 1  Staten Island
# 2          Bronx
# 3       Brooklyn
# 4         Queens

# %% [markdown]
# ## Question 6: Counting Rows
#
# Write a SQL query to count the number of subway stations in each borough in the `nyc_subway_stations` dataset.

# %%
# %%sql
# SELECT COUNT(ID) FROM nyc_subway_stations GROUP BY BOROUGH;
# Out:
#    count(ID)
# 0        170
# 1         90
# 2        140
# 3         22
# 4         69

# %% [markdown]
# ## Question 7: Aggregating Data
#
# Write a SQL query to list the number of subway stations in each borough, sorted in descending order by the count.

# %%
# %%sql
#
# SELECT COUNT(ID), BOROUGH FROM nyc_subway_stations
# GROUP BY BOROUGH
# ORDER BY COUNT(ID) DESC;
# Out:
# Deploy Panel apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup
#    count(ID)        BOROUGH
# 0        170       Brooklyn
# 1        140      Manhattan
# 2         90         Queens
# 3         69          Bronx
# 4         22  Staten Island

# %% [markdown]
# ## Question 8: Joining Tables
#
# Write a SQL query to join the `nyc_subway_stations` and `nyc_neighborhoods` datasets on the borough name, displaying the subway station name and the neighborhood name.

# %%
# %%sql
#
# SELECT nyc_subway_stations.NAME, nyc_subway_stations."BOROUGH", nyc_neighborhoods.NAME FROM nyc_subway_stations INNER JOIN nyc_neighborhoods ON nyc_subway_stations.BOROUGH = nyc_neighborhoods.BORONAME;
# Out:
#                     NAME    BOROUGH      NAME_1
# 0           Cortlandt St  Manhattan   Chinatown
# 1              Rector St  Manhattan   Chinatown
# 2            South Ferry  Manhattan   Chinatown
# 3               W 4th St  Manhattan   Chinatown
# 4                15th St   Brooklyn    Red Hook
# ...                  ...        ...         ...
# 11053     JFK Terminal 8     Queens  Auburndale
# 11054     Federal Circle     Queens  Auburndale
# 11055  Long Term Parking     Queens  Auburndale
# 11056       Howard Beach     Queens  Auburndale
# 11057            Jamaica     Queens  Auburndale
#
# [11058 rows x 3 columns]

# %% [markdown]
# ## Question 9: String Manipulation
#
# Write a SQL query to display the names of subway stations in the `nyc_subway_stations` dataset that contain the word "St" in their names.

# %%
# %%sql
#
# SELECT * FROM nyc_subway_stations WHERE NAME LIKE '%St%';
# Out:
#      OBJECTID     ID           NAME         ALT_NAME          CROSS_ST  \
# 0           1  376.0   Cortlandt St             None         Church St
# 1           2    2.0      Rector St             None              None
# 2           4  125.0       138th St  Grand Concourse   Grand Concourse
# 3           5  126.0       149th St  Grand Concourse   Grand Concourse
# 4           6   45.0       149th St  Grand Concourse   Grand Concourse
# ..        ...    ...            ...              ...               ...
# 225       422  252.0  Beach 98th St             None  Rockaway Freeway
# 226       438  177.0        Main St         Flushing     Roosevelt Ave
# 227       448  261.0    Steinway St             None          Broadway
# 228       475  469.0      St George             None              None
# 229       476  471.0      Stapleton             None              None
#
#                                   LONG_NAME                             LABEL  \
# ...

# %% [markdown]
# ## Question 10: Filtering with Multiple Conditions
#
# Write a SQL query to find all subway stations in the `nyc_subway_stations` dataset that are in the borough of Brooklyn and have routes that include the letter "R".

# %%
# %%sql
#
# SELECT * FROM nyc_subway_stations WHERE BOROUGH= 'Brooklyn' AND NAME Like '%R%';
# Out:
#    OBJECTID     ID           NAME  ALT_NAME      CROSS_ST  \
# 0       119  411.0  Bay Ridge Ave      None       4th Ave
# 1       124  388.0     Beverly Rd      None     E 16th St
# 2       125   96.0     Beverly Rd      None  Nostrand Ave
# 3       145  389.0   Cortelyou Rd      None     E 16th St
# 4       201  396.0        Neck Rd      None     E 16th St
# 5       220  228.0      Ralph Ave      None     Fulton St
# 6       221  229.0   Rockaway Ave      None     Fulton St
# 7       222   87.0   Rockaway Ave      None   Livonia Ave
# 8       223  462.0   Rockaway Pky  Canarsie   Glenwood Rd
#
#                               LONG_NAME                        LABEL  \
# 0            Bay Ridge Ave (R) Brooklyn            Bay Ridge Ave (R)
# 1               Beverly Rd (Q) Brooklyn               Beverly Rd (Q)
# 2             Beverly Rd (2,5) Brooklyn             Beverly Rd (2,5)
# 3             Cortelyou Rd (Q) Brooklyn             Cortelyou Rd (Q)
# ...
